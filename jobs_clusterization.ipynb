# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from data_collector import DataCollector
from collections import Counter

# %% [markdown]
# ## Загрузка данных

# %%
def update_database(store='postgres'):
    '''Get new vacancies and store them in local postgres database or,
    if it not set up, save as csv'''
    params = {
            'text': 'Name:(Аналитик данных) OR Name:(Data Scientist) OR Name:(Data Analyst) OR Name:(Data аналитик)',
            'area': [1, 2088, 2077, 2019], # 1 - Москва, 2088 - Зеленоград, 2077 - Химки
            'per_page': 100,
            'order_by': 'publication_time'
        }
    parser = DataCollector(params=params)
    try:
        vacancies = parser.collect_vacancies(store=store)
    except:
        vacancies = parser.collect_vacancies(store='csv')
    return vacancies

update_database()
vacancies = DataCollector.read_database()
vacancies.head()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 763/763 [01:44<00:00,  7.33it/s]
#                                    name  \
# id
# 45725967                 Data Scientist
# 46497855   Data analyst (Дата аналитик)
# 46427890          Senior Data Scientist
# 45646104  Аналитик Данных/ Data Analyst
# 44993248                Аналитик данных
#
#                                                    employer      from  to  \
# id
# 45725967                                           Wisebits    3500.0 NaN
# 46497855                                         ИЦ АЙ-ТЕКО       NaN NaN
# 46427890                                             Билайн       NaN NaN
# 45646104  Российская академия народного хозяйства и госу...       NaN NaN
# 44993248                                             Bip.ru  150000.0 NaN
#
#          currency                                        description  \
# id
# 45725967      EUR  WiseBits – продуктовый IT холдинг. Мы развивае...
# 46497855     None  Компания «Ай-Теко» - ведущий российский систем...
# 46427890     None  Наша команда Digital разрабатывает и внедряет ...
# 45646104     None  Центр подготовки руководителей цифровой трансф...
# 44993248      RUR  Bip.ru - продуктовая команда, которая семь лет...
#
#               city full_address                             url  \
# id
# 45725967  Лимассол     Лимассол  https://hh.ru/vacancy/45725967
# 46497855      None         None  https://hh.ru/vacancy/46497855
# 46427890      None         None  https://hh.ru/vacancy/46427890
# 45646104      None         None  https://hh.ru/vacancy/45646104
# 44993248      None         None  https://hh.ru/vacancy/44993248
#
#                                                  key_skills          schedule  \
# id
# 45725967  [Python, Математический анализ, Data Analysis,...  Удаленная работа
# 46497855  [Python, SQL, MS SQL, MS SQL Server, Data Mining]       Полный день
# 46427890  [Python, Linux, SQL, Математическая статистика...       Полный день
# 45646104     [Python, SQL, Power BI, Data Analysis, Pandas]     Гибкий график
# 44993248                                      [Python, SQL]       Полный день
#
#                                             specializations published_at  \
# id
# 45725967  [Информационные технологии, интернет, телеком,...   2021-09-13
# 46497855  [Банки, инвестиции, лизинг, Банки, инвестиции,...   2021-09-13
# 46427890  [Информационные технологии, интернет, телеком,...   2021-09-13
# 45646104     [Информационные технологии, интернет, телеком]   2021-09-13
# 44993248  [Информационные технологии, интернет, телеком,...   2021-09-13
#
#                   experience
# id
# 45725967       От 3 до 6 лет
# 46497855           Нет опыта
# 46427890  От 1 года до 3 лет
# 45646104  От 1 года до 3 лет
# 44993248  От 1 года до 3 лет

# %% [markdown]
# ## Посмотрим на топ 20 самых популярных умений во всех вакансиях и отдельно в вакансиях Data Scientist и Data Analyst

# %%
def get_key_skills(vacancies, top_n=20):
    '''Returns list of tuples (skill_name, % mentioned)
    where % mentioned is percentage of vacancies, where this skill was mentioned
    
    Note: vacancies where key skills were not specified are ignored
    
    '''
    ks_notnull_len = vacancies[vacancies.key_skills.astype(bool)].shape[0]
    skills_list = []
    [skills_list.extend(row) for row in vacancies.key_skills]
    top_skills = Counter(skills_list).most_common(top_n)
    return list(map(lambda x: (x[0], round(x[1] / ks_notnull_len * 100, 2)), top_skills))

data_analyst_vac = vacancies[vacancies.name.str.contains('[A,a]nalyst|[А,а]налитик')]
data_science_vac = vacancies[vacancies.name.str.contains('[S,s]cientist')]

all_ks = get_key_skills(vacancies)
DA_ks = get_key_skills(data_analyst_vac)
DS_ks = get_key_skills(data_science_vac)

skills_info = pd.DataFrame(zip(all_ks, DA_ks, DS_ks), 
                           columns=['Skill Name / Mentioned in % of all vacancies', 
                                    'Skill Name / Mentioned in % of DA vacancies', 
                                    'Skill Name / Mentioned in % of DS vacancies'])
skills_info
# Out:
#    Skill Name / Mentioned in % of all vacancies  \
# 0                                  (SQL, 68.22)
# 1                               (Python, 62.07)
# 2                        (Анализ данных, 22.19)
# 3                      (Английский язык, 15.59)
# 4            (Математическая статистика, 15.14)
# 5                        (MS PowerPoint, 11.24)
# 6               (Аналитическое мышление, 11.09)
# 7                        (Data Analysis, 10.49)
# 8                               (MS SQL, 10.34)
# 9                  (Статистический анализ, 9.0)
# 10                               (Tableau, 8.4)
# 11                          (Базы данных, 7.65)
# 12                              (Big Data, 7.5)
# 13                          (Data Mining, 7.05)
# 14                     (Machine Learning, 7.05)
# 15                                (Hadoop, 6.9)
# 16           (Аналитические исследования, 6.75)
# 17                               (Pandas, 6.45)
# 18                             (Power BI, 6.15)
# 19                        (Бизнес-анализ, 6.15)
#
#     Skill Name / Mentioned in % of DA vacancies  \
# 0                                  (SQL, 75.78)
# 1                               (Python, 51.35)
# 2                        (Анализ данных, 25.67)
# 3                      (Английский язык, 15.11)
# 4            (Математическая статистика, 14.29)
# 5                        (MS PowerPoint, 14.08)
# 6               (Аналитическое мышление, 13.87)
# 7                               (MS SQL, 13.66)
# 8                              (Tableau, 11.39)
# 9                        (Data Analysis, 10.77)
# 10                         (Базы данных, 10.14)
# 11                (Статистический анализ, 9.94)
# 12            (Аналитические исследования, 8.7)
# 13                             (Power BI, 8.07)
# 14                        (Бизнес-анализ, 8.07)
# 15                             (MS Excel, 7.66)
# 16  (Работа с большим объемом информации, 7.45)
# 17                          (Data Mining, 6.21)
# 18                           (PostgreSQL, 6.21)
# 19                              (Big Data, 6.0)
#
#    Skill Name / Mentioned in % of DS vacancies
# 0                              (Python, 89.42)
# 1                                 (SQL, 50.48)
# 2           (Математическая статистика, 21.15)
# 3                    (Machine Learning, 20.19)
# 4                     (Английский язык, 16.35)
# 5                        (Анализ данных, 14.9)
# 6                                  (ML, 13.94)
# 7                             (PyTorch, 13.94)
# 8                              (Pandas, 13.46)
# 9                        (Data Science, 13.46)
# 10                      (Data Analysis, 11.06)
# 11                        (Data Mining, 11.06)
# 12                                (NLP, 11.06)
# 13                             (Hadoop, 10.58)
# 14                           (Big Data, 10.58)
# 15                               (Spark, 9.62)
# 16                               (Linux, 9.13)
# 17               (Статистический анализ, 9.13)
# 18                               (Numpy, 8.65)
# 19        (Математическое моделирование, 8.65)

# %% [markdown]
# ## Поиск стажерских вакансий

# %%
vacancies[vacancies.name.str.contains('[С, с]тажер')]
# Out:
#                                                        name  \
# id
# 47715510                              Стажер data scientist
# 47519656                         Стажер-аналитик (Big Data)
# 47509593  Удаленный стажер аналитик (excel, olap, data m...
# 47504291                              Стажер Data Scientist
# 47260461  Удаленный стажер аналитик (анализ данных, data...
#
#                         employer  from       to currency  \
# id
# 47715510  СИБУР, Группа компаний   NaN      NaN     None
# 47519656           Т1 Консалтинг   NaN      NaN     None
# 47509593                МАЙНДСЭТ   NaN      NaN     None
# 47504291              СберМаркет   NaN  60000.0      RUR
# 47260461                МАЙНДСЭТ   NaN      NaN     None
#
#                                                 description  city  \
# id
# 47715510  О нас: Одно из ключевых направлений цифровизац...  None
# 47519656  Т1 Консалтинг – российская ИТ-компания, специа...  None
# 47509593  В учебный проект по исследованию табличных дан...  None
# 47504291  Sbermarket.ru (ex-Instamart) – стартап по дост...  None
# 47260461  Стажер - аналитик   Обязанности:   Написание н...  None
#
#          full_address                             url  \
# id
# 47715510         None  https://hh.ru/vacancy/47715510
# 47519656         None  https://hh.ru/vacancy/47519656
# 47509593         None  https://hh.ru/vacancy/47509593
# 47504291         None  https://hh.ru/vacancy/47504291
# 47260461         None  https://hh.ru/vacancy/47260461
#
#                                                  key_skills          schedule  \
# id
# 47715510                 [Python, SQL, R, machine learning]       Полный день
# 47519656                                                 []       Полный день
# 47509593  [Английский язык, MS PowerPoint, количественны...  Удаленная работа
# 47504291  [Python, SQL, Английский язык, ClickHouse, Spark]  Удаленная работа
# 47260461  [SQL, MS PowerPoint, Подготовка презентаций, M...  Удаленная работа
#
#                                             specializations published_at  \
# id
# 47715510                         [Начало карьеры, студенты]   2021-09-07
# 47519656  [Начало карьеры, студенты, Начало карьеры, сту...   2021-08-31
# 47509593  [Начало карьеры, студенты, Информационные техн...   2021-08-31
# 47504291  [Информационные технологии, интернет, телеком,...   2021-08-31
# 47260461                         [Начало карьеры, студенты]   2021-08-21
#
#          experience
# id
# 47715510  Нет опыта
# 47519656  Нет опыта
# 47509593  Нет опыта
# 47504291  Нет опыта
# 47260461  Нет опыта

# %% [markdown]
# ## Анализ зарплат
# Перевод зарплат в рубли

# %%
# convert price to rubles
def price_to_rur(vacancies):
    '''Convert salary to rubles'''
    ex_rate = {'USD': 72, 'EUR': 85}
    converted = vacancies.copy()
    
    convert_ind = vacancies[vacancies['currency'].isin(['USD', 'EUR'])].index
    rates = vacancies.loc[convert_ind, 'currency'].map(ex_rate)
    converted.loc[convert_ind, ['from', 'to']] = converted.loc[convert_ind, ['from', 'to']].multiply(rates, axis=0)
    converted.loc[convert_ind, 'currency'] = 'RUR'
    return converted

vac_rub = price_to_rur(vacancies)

# %% [markdown]
# Распределение зарплат

# %%
fig, ax = plt.subplots(1, 2, figsize=(14,6))
sns.histplot(vac_rub['from'], bins=12, ax=ax[0])
sns.histplot(vac_rub['to'], bins=12, ax=ax[1])
plt.tight_layout()

# %% [markdown]
# Сводная статистика по зарплатам

# %%
vac_rub[['from', 'to']].describe()
# Out:
#                 from             to
# count     102.000000      95.000000
# mean   138363.725490  192313.684211
# std     74719.098768  104962.042390
# min     30000.000000   40000.000000
# 25%     80000.000000  107500.000000
# 50%    130000.000000  180000.000000
# 75%    190000.000000  250000.000000
# max    350000.000000  500000.000000

# %% [markdown]
# Вакансии с наименьшей минимальной и наименьшей максимальной зарплатой

# %%
vac_rub.loc[vac_rub[['from', 'to']].idxmin()]
# Out:
#                                                  name      employer     from  \
# id
# 45716489  Оператор по сбору данных (полевой аналитик)         ЛАНИТ  30000.0
# 47475662                Аналитик данных BI (удаленно)  PLADO.MARKET  40000.0
#
#                to currency                                        description  \
# id
# 45716489      NaN      RUR  Команда компании SOLUT разрабатывает биометрич...
# 47475662  40000.0      RUR  Работа удаленная, с частичной занятостью (не м...
#
#           city full_address                             url  \
# id
# 45716489  None         None  https://hh.ru/vacancy/45716489
# 47475662  None         None  https://hh.ru/vacancy/47475662
#
#                                                  key_skills          schedule  \
# id
# 45716489  [Опрятный внешний вид, Работа в MS Office, Вид...       Полный день
# 47475662  [Управление проектами, Power BI, MS Power BI, ...  Удаленная работа
#
#                                             specializations published_at  \
# id
# 45716489  [Информационные технологии, интернет, телеком,...   2021-09-13
# 47475662  [Банки, инвестиции, лизинг, Бухгалтерия, управ...   2021-09-11
#
#                   experience
# id
# 45716489           Нет опыта
# 47475662  От 1 года до 3 лет

# %% [markdown]
# Вакансии с наибольшей минимальной и наибольшей максимальной зарплатой

# %%
vac_rub.loc[vac_rub[['from', 'to']].idxmax()]
# Out:
#                              name                  employer      from  \
# id
# 47948614  Teamlead data scientist  Кадровое агентство Юнити  350000.0
# 42493107      Lead Data Scientist                     РАБЛЗ       NaN
#
#                 to currency  \
# id
# 47948614       NaN      RUR
# 42493107  500000.0      RUR
#
#                                                 description  city  \
# id
# 47948614  Мы ищем опытного лидера команды, чтобы возглав...  None
# 42493107  Наша компания разрабатывает аналитические реше...  None
#
#          full_address                             url  \
# id
# 47948614         None  https://hh.ru/vacancy/47948614
# 42493107         None  https://hh.ru/vacancy/42493107
#
#                                                  key_skills          schedule  \
# id
# 47948614  [Python, SQL, Математическая статистика, Panda...  Удаленная работа
# 42493107  [Python, Hadoop, Spark, Git, Тестирование, Pro...     Гибкий график
#
#                                             specializations published_at  \
# id
# 47948614     [Информационные технологии, интернет, телеком]   2021-09-16
# 42493107  [Информационные технологии, интернет, телеком,...   2021-08-31
#
#              experience
# id
# 47948614    Более 6 лет
# 42493107  От 3 до 6 лет
